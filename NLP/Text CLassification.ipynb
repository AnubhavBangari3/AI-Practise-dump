# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/MyDrive/Colab Notebooks/nlp udemy"
# Out:
#  ARegular_expression
# 'Lematization and stop Words.ipynb'
# 'Named Entity Recognition.ipynb'
# 'NLP Basic.ipynb'
# 'NLP Tokenize Part 1.ipynb'
# 'Parts of Speech Tagging.ipynb'
#  python-regular-expressions-cheat-sheet.pdf
# 'regular expression practise.ipynb'
# 'Sentence Segmentation.ipynb'
#  spam.csv
#  Stemmer.ipynb
# 'Text CLassification.ipynb'
# 'Vocabulary and matching.ipynb'

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/nlp udemy/spam.csv",encoding="latin1")

# %%
df.head()#Label,Message,length,punct
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df['v1'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X=df["v2"]

# %%
y=df["v1"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect=CountVectorizer()

# %%
x_train_counts=count_vect.fit_transform(X_train)

# %%
x_train_counts
# Out:
# <3733x7057 sparse matrix of type '<class 'numpy.int64'>'
# 	with 49296 stored elements in Compressed Sparse Row format>

# %%
X_train.shape
# Out:
# (3733,)

# %%
x_train_counts.shape
# Out:
# (3733, 7057)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
t=TfidfTransformer()

# %%
X_t=t.fit_transform(x_train_counts)

# %%
X_t.shape
# Out:
# (3733, 7057)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec=TfidfVectorizer()

# %%
X_te=vec.fit_transform(X_train)

# %%
from sklearn.svm import LinearSVC

# %%
clf=LinearSVC()

# %%
clf.fit(X_te,y_train)
# Out:
# LinearSVC()

# %%
from sklearn.pipeline import Pipeline

# %%
text_clf=Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])

# %%
text_clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
pred=text_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1581    6]
#  [  27  225]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1587
#         spam       0.97      0.89      0.93       252
#
#     accuracy                           0.98      1839
#    macro avg       0.98      0.94      0.96      1839
# weighted avg       0.98      0.98      0.98      1839

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test,pred)
# Out:
# 0.9820554649265906

# %% [markdown]
# Movie review

# %%
#do the same for the moview review dataset
