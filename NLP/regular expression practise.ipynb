# %%
text="The phone number of the agent is 123-5546-2223.Call soon"

# %%
import re

# %%
pattern="phone"

# %%
re.search(pattern,text)
# Out:
# <re.Match object; span=(4, 9), match='phone'>

# %%
my_pattern=re.search(pattern,text)

# %%
my_pattern.span()
# Out:
# (4, 9)

# %%
my_pattern.start()
# Out:
# 4

# %%
my_pattern.end()
# Out:
# 9

# %%
text1="My phone is a new phone"

# %%
my_pattern1=re.search(pattern,text1)

# %%
my_pattern1.span()
# Out:
# (3, 8)

# %%
all_matches=re.findall(pattern,text1)

# %%
all_matches
# Out:
# ['phone', 'phone']

# %%
for match in re.finditer(pattern,text1):
  print(match.span())
# Out:
# (3, 8)
# (18, 23)

# %%
text
# Out:
# 'The phone number of the agent is 123-5546-2223.Call soon'

# %%
pattern=r'\d\d\d-\d\d\d\d-\d\d\d\d'

# %%
p=re.search(pattern,text)

# %%
p
# Out:
# <re.Match object; span=(33, 46), match='123-5546-2223'>

# %%
p.group()
# Out:
# '123-5546-2223'

# %%
pattern=r'\d{3}-\d{4}-\d{4}'

# %%
p=re.search(pattern,text)
# Out:
# <re.Match object; span=(33, 46), match='123-5546-2223'>

# %%
p.group()
# Out:
# '123-5546-2223'

# %%
pattern=r'(\d{3})-(\d{4})-(\d{4})'

# %%
p=re.search(pattern,text)

# %%
p.group(1)
# Out:
# '123'

# %%
p.group(2)
# Out:
# '5546'

# %%
t="Anubhav Bangari is a millionaire"

# %%
check=r"Anubhav|Khushi"

# %%
re.findall(check,t)
# Out:
# ['Anubhav']

# %%
re.findall(r".at","Bat and bowl")
# Out:
# ['Bat']

# %%
re.findall(r"\d$","This end with 29")
# Out:
# ['9']

# %%
re.findall(r"^\d","29 This start with 2")
# Out:
# ['2']

# %%
phrase="There are two numbers in 29 which is 2 and 9"

# %%
re.findall(r"[^\d]+",phrase)
# Out:
# ['There are two numbers in ', ' which is ', ' and ']

# %%
test_phrase="Oh My god! India is the best.Right?"

# %%
my=re.findall(r"[^!.?]+",test_phrase)

# %%
my
# Out:
# ['Oh My god', ' India is the best', 'Right']

# %%
"".join(my)
# Out:
# 'Oh My god India is the bestRight'

# %%
text2="Only find the hyphen words.where are the long-ish dash words?"

# %%
re.findall(r"[\w]+",text2)
# Out:
# ['Only',
#  'find',
#  'the',
#  'hyphen',
#  'words',
#  'where',
#  'are',
#  'the',
#  'long',
#  'ish',
#  'dash',
#  'words']
