# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
from spacy.matcher import Matcher

# %%
matcher=Matcher(nlp.vocab)

# %%
pattern1=[{'LOWER':'solarpower'}]
pattern2=[{'LOWER':'solar'},{'IS_PUNCT':True},{'LOWER':"power"}]
pattern3=[{'LOWER':'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower',[pattern1,pattern2,pattern3])

# %%
doc=nlp(u"The Solar Power industry continues to grow a sloarpower increases.Solar-power is great")

# %%
found_matches=matcher(doc)

# %%
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 11, 14)]

# %%
for match_id, start, end in found_matches:
    matched_text = doc[start:end].text
    print(f"Matched '{matched_text}' with pattern ID '{match_id}'.Start:{start} End:{end}")
# Out:
# Matched 'Solar Power' with pattern ID '8656102463236116519'.Start:1 End:3
# Matched 'Solar-power' with pattern ID '8656102463236116519'.Start:11 End:14

# %%
from spacy.matcher import PhraseMatcher

# %%
pMatcher=PhraseMatcher(nlp.vocab)

# %%
#Use the above for Phrase matching.
#Do it like the same way you did above
