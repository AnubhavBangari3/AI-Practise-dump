# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/MyDrive/Colab Notebooks/2023 Starting Again/Pandas Practise/Pokemon Dataset"
# Out:
# pokemon.csv  pokemon.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/2023 Starting Again/Pandas Practise/Pokemon Dataset/pokemon.csv")

# %%
df.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df["type1"].value_counts().plot(kind="pie",autopct='%.1f%%',figsize=(8,8))
# Out:
# <Axes: ylabel='type1'>

# %%
df["type2"].value_counts().plot(kind="pie",autopct='%.1f%%',figsize=(8,8))
# Out:
# <Axes: ylabel='type2'>

# %% [markdown]
# #Legendary Pokemon

# %%
df["is_legendary"].value_counts().plot(kind="pie",autopct='%.1f%%',cmap='Set3',figsize=(6,6))
# Out:
# <Axes: ylabel='is_legendary'>

# %% [markdown]
# #How many Pokemon exist with an attack value greater than 150?

# %%
val_gt_150=df["attack"].value_counts()>150
val_gt_150.count()
# Out:
# 114

# %%
val_gt_150.describe()
# Out:
# count       114
# unique        1
# top       False
# freq        114
# Name: attack, dtype: object

# %%
val_gt_150.shape
# Out:
# (114,)

# %%
sns.boxplot(data=df,x="attack")
# Out:
# <Axes: xlabel='attack'>

# %% [markdown]
# #Select all the pokemon with speed of 10 or less

# %%
df[df["speed"]<=10]
# Out:
#                                          abilities  against_bug  against_dark  \
# 212             ['Sturdy', 'Gluttony', 'Contrary']          1.0           1.0
# 327  ['Hyper Cutter', 'Arena Trap', 'Sheer Force']          1.0           1.0
# 437             ['Sturdy', 'Rock Head', 'Rattled']          1.0           1.0
# 445            ['Pickup', 'Thick Fat', 'Gluttony']          1.0           1.0
# 596                                 ['Iron Barbs']          1.0           1.0
# 770                     ['Innards Out', 'Unaware']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 212             1.0               1.0            1.0            1.0
# 327             1.0               0.0            1.0            1.0
# 437             1.0               1.0            1.0            2.0
# 445             1.0               1.0            1.0            2.0
# 596             0.5               0.5            0.5            2.0
# ...

# %%
sns.boxplot(data=df,x="speed")
# Out:
# <Axes: xlabel='speed'>

# %% [markdown]
# #Get all legendary Pokemon

# %%
df[df["is_legendary"] == 1]
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# 143  ['Pressure', 'Snow Cloak']         0.50           1.0             1.0
# 144      ['Pressure', 'Static']         0.50           1.0             1.0
# 145  ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 149     ['Pressure', 'Unnerve']         2.00           2.0             1.0
# 150             ['Synchronize']         2.00           2.0             1.0
# ..                          ...          ...           ...             ...
# 796             ['Beast Boost']         0.25           1.0             0.5
# 797             ['Beast Boost']         1.00           1.0             0.5
# 798             ['Beast Boost']         2.00           0.5             2.0
# 799             ['Prism Armor']         2.00           2.0             1.0
# 800              ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# ...

# %% [markdown]
# #Find a Pokemon with low defence and high attack

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
defense_and_attack=df.sort_values(by=["defense","attack"],ascending=[False,True]).head(5)
print(defense_and_attack["defense"])
# Out:
# 212    230
# 207    230
# 305    230
# 376    200
# 712    184
# Name: defense, dtype: int64

# %% [markdown]
# #How many Fire flying pokemon are there?

# %%
(df["type1"]=="fire").sum()
# Out:
# 52

# %%
(df["type2"]=="flying").sum()
# Out:
# 95

# %%
(
    (df["type1"]=="fire") & (df["type2"]=="flying")
).sum()
# Out:
# 6

# %%
df.loc[(df["type1"]=="fire") & (df["type2"]=="flying")]
# Out:
#                         abilities  against_bug  against_dark  against_dragon  \
# 5        ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 145    ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 249   ['Pressure', 'Regenerator']         0.25           1.0             1.0
# 661  ['Flame Body', 'Gale Wings']         0.25           1.0             1.0
# 662  ['Flame Body', 'Gale Wings']         0.25           1.0             1.0
# 740                    ['Dancer']         0.25           1.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 5                 2.0            0.5            0.5           0.5
# 145               2.0            0.5            0.5           0.5
# 249               2.0            0.5            0.5           0.5
# 661               2.0            0.5            0.5           0.5
# 662               2.0            0.5            0.5           0.5
# ...

# %% [markdown]
# #WHich pokemon of typ1 ice has the strongest defense

# %%
df[df["type1"]=="ice"].sort_values(by="defense",ascending=False).max()["name"]
# Out:
# <ipython-input-66-0b656e87de82>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["type1"]=="ice"].sort_values(by="defense",ascending=False).max()["name"]
# 'Walrein'

# %% [markdown]
# #what's the most common type of legenday pokemon?

# %%
df.loc[df['is_legendary']==1,'type2'].value_counts()
# Out:
# flying      10
# fighting     6
# fairy        6
# psychic      4
# dragon       4
# steel        4
# grass        2
# fire         2
# ghost        2
# electric     1
# ice          1
# ground       1
# water        1
# poison       1
# Name: type2, dtype: int64

# %%
df.loc[df['is_legendary']==1,'type2'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.loc[df['is_legendary']==1,'type1'].value_counts()
# Out:
# psychic     17
# dragon       7
# water        6
# steel        6
# electric     5
# fire         5
# rock         4
# grass        4
# normal       3
# dark         3
# bug          3
# ice          2
# ground       2
# ghost        1
# flying       1
# fairy        1
# Name: type1, dtype: int64

# %%
df.loc[df['is_legendary']==1,'type1'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# #WHich is the strongest water pokemon from 1st 3 generation of water?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df["base_total"].head(5)
# Out:
# 0    318
# 1    405
# 2    625
# 3    309
# 4    405
# Name: base_total, dtype: int64

# %%
df.loc[df["generation"]<=3,"type1"]
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 381      water
# 382     ground
# 383     dragon
# 384      steel
# 385    psychic
# Name: type1, Length: 386, dtype: object

# %%
df.loc[(df["type1"]=="water") & (df["generation"].isin([1,2,3]))].sort_values(by="base_total",ascending=False).max()["name"]
# Out:
# <ipython-input-98-7736c1d19f48>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[(df["type1"]=="water") & (df["generation"].isin([1,2,3]))].sort_values(by="base_total",ascending=False).max()["name"]
# 'Wooper'

# %% [markdown]
# #Most powerful dragon from the last 2 generation

# %%
df["generation"].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     80
# 6     72
# Name: generation, dtype: int64

# %%
df.loc[(df["type1"]=="dragon") | (df["type2"]=="dragon") & (df["generation"].isin([5,6]))].sort_values(by="base_total",ascending=False).max()["name"]
# Out:
# <ipython-input-102-b0a3e99b3196>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[(df["type1"]=="dragon") | (df["type2"]=="dragon") & (df["generation"].isin([5,6]))].sort_values(by="base_total",ascending=False).max()["name"]
# 'Zygarde'

# %% [markdown]
# #Select the most powerful fire pokemon

# %%
df.loc[(df["type1"]=="fire") | (df["type2"]=="fire")].sort_values(by="base_total",ascending=False).max()["name"]
# Out:
# <ipython-input-103-cbd7b4f03b01>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[(df["type1"]=="fire") | (df["type2"]=="fire")].sort_values(by="base_total",ascending=False).max()["name"]
# 'Vulpix'

# %% [markdown]
# #Legendary pokemon fo type fire

# %%
l=df.loc[(df["type1"] =="fire")&df["is_legendary"],
         ['name','attack','generation']]
print(l)
# Out:
#           name  attack  generation
# 145    Moltres     100           1
# 243      Entei     115           2
# 249      Ho-Oh     130           2
# 484    Heatran      90           4
# 720  Volcanion     110           6
