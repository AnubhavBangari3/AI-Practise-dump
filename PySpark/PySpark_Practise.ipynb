# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.3)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql.functions import *

# %% [markdown]
# ### Create Spark Session

# %%
spark=SparkSession.builder.appName("CrashCourse").getOrCreate()

# %%
print(spark.version)
# Out:
# 4.0.3

# %% [markdown]
# ### Create DataFrame

# %%
df=spark.createDataFrame([(1,"A",25),(2,"B",28),(3,"C",32)],["id","name","age"])

# %%
df.show()
# Out:
# +---+----+---+
# | id|name|age|
# +---+----+---+
# |  1|   A| 25|
# |  2|   B| 28|
# |  3|   C| 32|
# +---+----+---+

# %% [markdown]
# ### Read CSV File

# %%
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/Pyspark and pytorch"
# Out:
#  employees.csv	'PySpark Practise.ipynb'  'Pytorch Practise 1.ipynb'

# %%
df=spark.read.csv("/content/drive/MyDrive/Colab Notebooks/Pyspark and pytorch/employees.csv",header=True,inferSchema=True)

# %%
df.show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+

# %%
df.describe().show()
# Out:
# +-------+----------------+-----+-----------------+------+----------+---------+------------------+-----------------+
# |summary|     employee_id| name|              age|gender|department|     city|            salary|       experience|
# +-------+----------------+-----+-----------------+------+----------+---------+------------------+-----------------+
# |  count|              15|   15|               15|    15|        15|       15|                15|               15|
# |   mean|             8.0| NULL|             30.2|  NULL|      NULL|     NULL|           88600.0|6.133333333333334|
# | stddev|4.47213595499958| NULL|3.342368706685211|  NULL|      NULL|     NULL|12205.385228309207|2.722044049886741|
# |    min|               1| Amit|               25|Female|        AI|Bangalore|             70000|                2|
# |    max|              15|Vikas|               36|  Male|     MLOps|     Pune|            110000|               11|
# +-------+----------------+-----+-----------------+------+----------+---------+------------------+-----------------+

# %%
df.printSchema()
# Out:
# root
#  |-- employee_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- experience: integer (nullable = true)
#  |-- joining_date: date (nullable = true)

# %%
df.columns
# Out:
# ['employee_id',
#  'name',
#  'age',
#  'gender',
#  'department',
#  'city',
#  'salary',
#  'experience',
#  'joining_date']

# %%
df.count()
# Out:
# 15

# %% [markdown]
# ### Select Specific Column

# %%
df.select("name").show()
# Out:
# +--------+
# |    name|
# +--------+
# |Shridhar|
# |    Amit|
# |    Neha|
# |   Priya|
# |   Rahul|
# |   Sneha|
# |   Karan|
# |  Anjali|
# |   Vikas|
# |   Pooja|
# |   Arjun|
# |   Kavya|
# |   Rohan|
# |   Meera|
# |   Sahil|
# +--------+

# %%
df.select("name","salary").show()
# Out:
# +--------+------+
# |    name|salary|
# +--------+------+
# |Shridhar| 85000|
# |    Amit| 95000|
# |    Neha| 78000|
# |   Priya| 88000|
# |   Rahul|105000|
# |   Sneha| 72000|
# |   Karan| 91000|
# |  Anjali| 83000|
# |   Vikas| 99000|
# |   Pooja| 70000|
# |   Arjun| 81000|
# |   Kavya|102000|
# |   Rohan| 76000|
# |   Meera| 94000|
# |   Sahil|110000|
# +--------+------+

# %%
df.select(col("salary").alias("income")).show()
# Out:
# +------+
# |income|
# +------+
# | 85000|
# | 95000|
# | 78000|
# | 88000|
# |105000|
# | 72000|
# | 91000|
# | 83000|
# | 99000|
# | 70000|
# | 81000|
# |102000|
# | 76000|
# | 94000|
# |110000|
# +------+

# %%
df.selectExpr("salary*12 as annual_salary").show()
# Out:
# +-------------+
# |annual_salary|
# +-------------+
# |      1020000|
# |      1140000|
# |       936000|
# |      1056000|
# |      1260000|
# |       864000|
# |      1092000|
# |       996000|
# |      1188000|
# |       840000|
# |       972000|
# |      1224000|
# |       912000|
# |      1128000|
# |      1320000|
# +-------------+

# %% [markdown]
# ### Filter Rows

# %%
df.filter(col("age")>10).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+

# %%
df.filter((col("age")>10)&(col("city")=="Pune")).show()
# Out:
# +-----------+--------+---+------+----------------+----+------+----------+------------+
# |employee_id|    name|age|gender|      department|city|salary|experience|joining_date|
# +-----------+--------+---+------+----------------+----+------+----------+------------+
# |          1|Shridhar| 29|  Male|              AI|Pune| 85000|         5|  2021-01-15|
# |          3|    Neha| 27|Female|    Data Science|Pune| 78000|         4|  2022-03-20|
# |          7|   Karan| 31|  Male|              AI|Pune| 91000|         7|  2019-04-05|
# |         11|   Arjun| 29|  Male|    Data Science|Pune| 81000|         5|  2020-11-21|
# |         14|   Meera| 31|Female|Data Engineering|Pune| 94000|         7|  2019-09-12|
# +-----------+--------+---+------+----------------+----+------+----------+------------+

# %%
df.filter((col("age")>30)|(col("city")=="Pune")).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+

# %%
df.filter(col("department").isin("AI","MLOps")).show()
# Out:
# +-----------+--------+---+------+----------+---------+------+----------+------------+
# |employee_id|    name|age|gender|department|     city|salary|experience|joining_date|
# +-----------+--------+---+------+----------+---------+------+----------+------------+
# |          1|Shridhar| 29|  Male|        AI|     Pune| 85000|         5|  2021-01-15|
# |          4|   Priya| 30|Female|        AI|Bangalore| 88000|         6|  2020-07-11|
# |          5|   Rahul| 35|  Male|     MLOps|    Delhi|105000|        10|  2016-09-01|
# |          7|   Karan| 31|  Male|        AI|     Pune| 91000|         7|  2019-04-05|
# |          8|  Anjali| 28|Female|     MLOps|   Mumbai| 83000|         4|  2021-08-18|
# |         10|   Pooja| 25|Female|        AI|Bangalore| 70000|         2|  2024-01-05|
# |         12|   Kavya| 33|Female|     MLOps|Hyderabad|102000|         8|  2018-12-30|
# |         13|   Rohan| 27|  Male|        AI|   Mumbai| 76000|         3|  2022-06-01|
# |         15|   Sahil| 36|  Male|     MLOps|Bangalore|110000|        11|  2015-04-08|
# +-----------+--------+---+------+----------+---------+------+----------+------------+

# %% [markdown]
# ### Add New Column

# %%
df.withColumn("country",lit("India")).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|country|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|  India|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|  India|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|  India|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|  India|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|  India|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|  India|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|  India|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|  India|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|  India|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|  India|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|  India|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|  India|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|  India|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|  India|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|  India|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+

# %%
df.withColumn("bonus",col("salary")*0.2).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|  bonus|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|17000.0|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|19000.0|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|15600.0|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|17600.0|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|21000.0|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|14400.0|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|18200.0|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|16600.0|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|19800.0|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|14000.0|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|16200.0|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|20400.0|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|15200.0|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|18800.0|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|22000.0|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+-------+

# %%
df.withColumn("annualSalary",col("salary")*12).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date|annualSalary|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|     1020000|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|     1140000|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|      936000|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|     1056000|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|     1260000|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|      864000|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|     1092000|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|      996000|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|     1188000|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|      840000|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|      972000|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|     1224000|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|      912000|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|     1128000|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|     1320000|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------------+

# %%
df.withColumn("level",when(col("experience")>5,"Senior").otherwise("Junior")).show()
# Out:
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------+
# |employee_id|    name|age|gender|      department|     city|salary|experience|joining_date| level|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------+
# |          1|Shridhar| 29|  Male|              AI|     Pune| 85000|         5|  2021-01-15|Junior|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai| 95000|         8|  2018-06-10|Senior|
# |          3|    Neha| 27|Female|    Data Science|     Pune| 78000|         4|  2022-03-20|Junior|
# |          4|   Priya| 30|Female|              AI|Bangalore| 88000|         6|  2020-07-11|Senior|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|105000|        10|  2016-09-01|Senior|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad| 72000|         3|  2023-01-01|Junior|
# |          7|   Karan| 31|  Male|              AI|     Pune| 91000|         7|  2019-04-05|Senior|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai| 83000|         4|  2021-08-18|Junior|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi| 99000|         9|  2017-02-14|Senior|
# |         10|   Pooja| 25|Female|              AI|Bangalore| 70000|         2|  2024-01-05|Junior|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune| 81000|         5|  2020-11-21|Junior|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|102000|         8|  2018-12-30|Senior|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai| 76000|         3|  2022-06-01|Junior|
# |         14|   Meera| 31|Female|Data Engineering|     Pune| 94000|         7|  2019-09-12|Senior|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|110000|        11|  2015-04-08|Senior|
# +-----------+--------+---+------+----------------+---------+------+----------+------------+------+

# %% [markdown]
# ### Rename Column

# %%
df.withColumnRenamed("salary","monthly_salary").show()
# Out:
# +-----------+--------+---+------+----------------+---------+--------------+----------+------------+
# |employee_id|    name|age|gender|      department|     city|monthly_salary|experience|joining_date|
# +-----------+--------+---+------+----------------+---------+--------------+----------+------------+
# |          1|Shridhar| 29|  Male|              AI|     Pune|         85000|         5|  2021-01-15|
# |          2|    Amit| 32|  Male|Data Engineering|   Mumbai|         95000|         8|  2018-06-10|
# |          3|    Neha| 27|Female|    Data Science|     Pune|         78000|         4|  2022-03-20|
# |          4|   Priya| 30|Female|              AI|Bangalore|         88000|         6|  2020-07-11|
# |          5|   Rahul| 35|  Male|           MLOps|    Delhi|        105000|        10|  2016-09-01|
# |          6|   Sneha| 26|Female|    Data Science|Hyderabad|         72000|         3|  2023-01-01|
# |          7|   Karan| 31|  Male|              AI|     Pune|         91000|         7|  2019-04-05|
# |          8|  Anjali| 28|Female|           MLOps|   Mumbai|         83000|         4|  2021-08-18|
# |          9|   Vikas| 34|  Male|Data Engineering|    Delhi|         99000|         9|  2017-02-14|
# |         10|   Pooja| 25|Female|              AI|Bangalore|         70000|         2|  2024-01-05|
# |         11|   Arjun| 29|  Male|    Data Science|     Pune|         81000|         5|  2020-11-21|
# |         12|   Kavya| 33|Female|           MLOps|Hyderabad|        102000|         8|  2018-12-30|
# |         13|   Rohan| 27|  Male|              AI|   Mumbai|         76000|         3|  2022-06-01|
# |         14|   Meera| 31|Female|Data Engineering|     Pune|         94000|         7|  2019-09-12|
# |         15|   Sahil| 36|  Male|           MLOps|Bangalore|        110000|        11|  2015-04-08|
# +-----------+--------+---+------+----------------+---------+--------------+----------+------------+
