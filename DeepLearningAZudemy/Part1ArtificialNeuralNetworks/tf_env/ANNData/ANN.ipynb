# %% [markdown]
# # Aritificial Neural Network

# %% [markdown]
# ### 1) Data Preprocessing

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 23.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\anubh\anaconda3\AI\AI-Practise-dump\Deep Learning A-Z udemy\Part 1 - Artificial Neural Networks (ANN)\tf_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#      --------------------------------------- 11.3/11.3 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ------------------------------------- 509.2/509.2 KB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-2.3.3 pytz-2025.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\anubh\anaconda3\AI\AI-Practise-dump\Deep Learning A-Z udemy\Part 1 - Artificial Neural Networks (ANN)\tf_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install -U matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from matplotlib) (2.2.6)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
#      ---------------------------------------- 221.2/221.2 KB ? eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 24.8 MB/s eta 0:00:00
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
#      ---------------------------------------- 121.8/121.8 KB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Downloading pillow-12.1.0-cp310-cp310-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 18.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
#      ---------------------------------------- 73.7/73.7 KB ? eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\anubh\anaconda3\AI\AI-Practise-dump\Deep Learning A-Z udemy\Part 1 - Artificial Neural Networks (ANN)\tf_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the csv file

# %%
data=pd.read_csv("Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
 X=data.iloc[:,3:-1].values #Start from colum index 3 till the second last column (Except the Last column)

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
y=data.iloc[:,-1].values #Contains the Last column only

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
print(X.shape,y.shape)
# Out:
# (10000, 10) (10000,)

# %% [markdown]
# ### 2) Encoding Categorical Data

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#      ---------------------------------------- 8.9/8.9 MB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from scikit-learn) (2.2.6)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      ------------------------------------- 309.1/309.1 KB 19.9 MB/s eta 0:00:00
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#      --------------------------------------- 41.3/41.3 MB 18.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\anubh\anaconda3\AI\AI-Practise-dump\Deep Learning A-Z udemy\Part 1 - Artificial Neural Networks (ANN)\tf_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %% [markdown]
# #### Label Encoding Gender

# %%
X[:,2]=le.fit_transform(X[:,2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# #### One hot encoding the Geography Column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct= ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])],remainder='passthrough')

# %%
X=np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# #### Splitting the data into Training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# ## 3) Building ANN

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (22.0.4)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorflow) (2.2.6)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.18.0-cp310-cp310-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anubh\anaconda3\ai\ai-practise-dump\deep learning a-z udemy\part 1 - artificial neural networks (ann)\tf_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
#    ---------------------------------------- 0.0/331.7 MB ? eta -:--:--
#     --------------------------------------- 5.0/331.7 MB 25.2 MB/s eta 0:00:13
#    - -------------------------------------- 10.5/331.7 MB 26.2 MB/s eta 0:00:13
#    - -------------------------------------- 13.1/331.7 MB 20.6 MB/s eta 0:00:16
#    -- ------------------------------------- 19.1/331.7 MB 22.8 MB/s eta 0:00:14
#    --- ------------------------------------ 25.4/331.7 MB 24.0 MB/s eta 0:00:13
#    --- ------------------------------------ 32.0/331.7 MB 25.1 MB/s eta 0:00:12
#    ---- -----------------------------------
4 MB/s eta 0:00:04
#    ---------------------------- ---------- 242.2/331.7 MB 25.3 MB/s eta 0:00:04
#    ---------------------------- ---------- 246.2/331.7 MB 25.1 MB/s eta 0:00:04
#    ----------------------------- --------- 250.1/331.7 MB 25.0 MB/s eta 0:00:04
#    ----------------------------- --------- 254.3/331.7 MB 24.8 MB/s eta 0:00:04
#    ------------------------------ -------- 259.0/331.7 MB 24.8 MB/s eta 0:00:03
#    ------------------------------- ------- 263.7/331.7 MB 24.7 MB/s eta 0:00:03
#    ------------------------------- ------- 269.7/331.7 MB 24.8 MB/s eta 0:00:03
#    -------------------------------- ------ 275.8/331.7 MB 25.1 MB/s eta 0:00:03
#    -------------------------------- ------ 279.2/331.7 MB 24.8 MB/s eta 0:00:03
#    --------------------------------- ----- 280.8/331.7 MB 24.5 MB/s eta 0:00:03
#    --------------------------------- ----- 283.6/331.7 MB 24.2 MB/s eta 0:00:02
#    --------------------------------- ----- 287.0/331.7 MB 24.0 MB/s eta 0:00:02
#    ---------------------------------- ---- 292.6/331.7 MB 24.0 MB/s eta 0:00:02
#    ----------------------------------- --- 298.3/331.7 MB 23.9 MB/s eta 0:00:02
#    ----------------------------------- --- 302.8/331.7 MB 23.7 MB/s eta 0:00:02
#    ------------------------------------ -- 307.0/331.7 MB 23.7 MB/s eta 0:00:02
#    ------------------------------------ -- 310.9/331.7 MB 23.6 MB/s eta 0:00:01
#    ------------------------------------ -- 314.6/331.7 MB 23.4 MB/s eta 0:00:01
#    ------------------------------------- - 321.4/331.7 MB 23.5 MB/s eta 0:00:01
#    --------------------------------------  326.6/331.7 MB 23.5 MB/s eta 0:00:01
#    --------------------------------------  329.5/331.7 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 23.3 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 23.3 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 23.3 MB/s eta 0:00:01
#    ---------------------------------------- 331.7/331.7 MB 22.0 MB/s  0:00:14
# Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 4.7/4.7 MB 23.8 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------------ --------------------- 2.6/5.5 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 14.7 MB/s  0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 27.8 MB/s  0:00:00
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 25.8 MB/s  0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Downloading wrapt-2.0.1-cp310-cp310-win_amd64.whl (60 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.18.0-cp310-cp310-win_amd64.whl (302 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt_einsum, ml_dtypes, mdurl, markdown, h5py, grpcio, google_pasta, gast, absl-py, tensorboard, markdown-it-py, astunparse, rich, keras, tensorflow
#
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    --- ------------------------------------  2/25 [flatbuffers]
#    ------ ---------------------------------  4/25 [wheel]
#    -------- -------------------------------  5/25 [werkzeug]
#    -------- -------------------------------  5/25 [werkzeug]
#    ------------ ---------------------------  8/25 [protobuf]
#    ------------ ---------------------------  8/25 [protobuf]
#    ---------------- ----------------------- 10/25 [opt_einsum]
#    ------------------- -------------------- 12/25 [mdurl]
#    -------------------- ------------------- 13/25 [markdown]
#    ---------------------- ----------------- 14/25 [h5py]
#    ---------------------- ----------------- 14/25 [h5py]
#    ------------------------ --------------- 15/25 [grpcio]
#    ------------------------ --------------- 15/25 [grpcio]
#    ------------------------- -------------- 16/25 [google_pasta]
#    ---------------------------- ----------- 18/25 [absl-py]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    ------------------------------ --------- 19/25 [tensorboard]
#    -------------------------------- ------- 20/25 [markdown-it-py]
#    -------------------------------- ------- 20/25 [markdown-it-py]
#    ----------------------------------- ---- 22/25 [rich]
#    ----------------------------------- ---- 22/25 [rich]
#    ----------------------------------- ---- 22/25 [rich]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#